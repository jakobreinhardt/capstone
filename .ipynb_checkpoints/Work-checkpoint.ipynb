# %% [markdown]
# **INTRODUCTION**
#
# This notebook is used to anser research questions for the capstone project for the Data Science Nanodegree on Udacity.
#
# I use the dataset provided by Our World in Data (https://github.com/owid/covid-19-data/tree/master/public/data). I started the project on 2021-11-26, hence, in order to be able to work with stable conclusions about the data, I use the dataset downloded on that day.
#
# I want to answer research questions about the COVID 19 Pandemic which you and read more about in the associated blog post: https://medium.com/@jakob.reinhardt/the-analysis-of-covid-19-data-d5ddaacce88d

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import scipy.stats
import random
from collections import Counter
# %matplotlib inline

# %%
# Reading Data
data = pd.read_csv('owid-covid-data.csv')

# %% [markdown]
# ## Analysis

# %%
# Data Exploration
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
data.shape
# Out:
# (135794, 67)

# %%
len(data.location.unique())
# Out:
# 237

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
# overview over missing values
for column in data.columns:
    print(data[column].isna().value_counts())
# Out:
# False    135794
# Name: iso_code, dtype: int64
# False    127138
# True       8656
# Name: continent, dtype: int64
# False    135794
# Name: location, dtype: int64
# False    135794
# Name: date, dtype: int64
# False    128308
# True       7486
# Name: total_cases, dtype: int64
# False    128303
# True       7491
# Name: new_cases, dtype: int64
# False    127263
# True       8531
# Name: new_cases_smoothed, dtype: int64
# False    117079
# True      18715
# Name: total_deaths, dtype: int64
# False    117275
# True      18519
# Name: new_deaths, dtype: int64
# False    127263
# True       8531
# Name: new_deaths_smoothed, dtype: int64
# False    127650
# True       8144
# Name: total_cases_per_million, dtype: int64
# False    127645
# True       8149
# Name: new_cases_per_million, dtype: int64
# False    126610
# True       9184
# Name: new_cases_smoothed_per_million, dtype: int64
# False    116434
# True      19360
# Name: total_deaths_per_million, dtype: int64
# False    116630
# ...

# %%
#fraction of missing values in 'new_cases_smoothed_per_million'
data['new_cases_smoothed_per_million'].isna().sum()/data['new_cases_smoothed_per_million'].shape[0]
# Out:
# 0.06763185413199405

# %%
# fraction of missing values in full dataset
data.isna().sum().sum()/(data.shape[0]*data.shape[1])
# Out:
# 0.44857893837878665

# %% [markdown]
# In the following I want to answer the research question on which countries are similar in terms of COVID metrics

# %%
def plot_countries(country_1, country_2, metric):
    '''
    plots metric for two countries over time
    
    input: 
        string: names of country_1 and country_2
        string: metric to display
    output: none
    '''
    country_1 = data[data['location']==country_1]
    country_2 = data[data['location']==country_2]
    
    plt.rcParams["figure.figsize"] = (12,6)
    plt.plot(range(len(country_1['date'])), country_1[metric]);
    plt.plot(range(len(country_2['date'])), country_2[metric]);
    plt.xlabel('Days since 2020-01-24')
    plt.ylabel(metric)
    plt.title('New infections for different countries')
    plt.legend([country_1['location'].iloc[0], country_2['location'].iloc[0]])
    plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
plot_countries('Austria', 'Switzerland', 'new_cases_smoothed_per_million')

# %% [markdown]
# ## Methodology

# %%
def clean_and_correlate(country_1, country_2, metric):
    '''
    drops rows with missing values
    removes rows with dates that are in country 1 but not in country 2 and vice versa
    correlates country 1 to country 2 according to the metric
    
    Input: 
        string: names of country_1 and country_2
        string: metric to clean data for

    Output: pearson correlation R score and P-Value 
    '''
    country_1 = data[data['location']==country_1]
    country_2 = data[data['location']==country_2]
    
    # drop rows with NaNs in both countries accordingly
    country_1.dropna(inplace=True, subset=[metric])
    country_2.dropna(inplace=True, subset=[metric])
    
    # find and remove inconsistend dates
    dates_to_drop_1 = np.setdiff1d(country_1['date'], country_2['date'], assume_unique=False)
    dates_to_drop_2 = np.setdiff1d(country_2['date'], country_1['date'], assume_unique=False)
    
    dates_indexes_1 = []
    for date in dates_to_drop_1:
        dates_indexes_1.append(country_1.index[country_1['date'] == date][0])

    dates_indexes_2 = []
    for date in dates_to_drop_2:
        dates_indexes_2.append(country_2.index[country_2['date'] == date][0])
        
    country_1.drop(dates_indexes_1 , axis = 0, inplace = True)
    country_2.drop(dates_indexes_2 , axis = 0, inplace = True)
    
    r , p = scipy.stats.pearsonr(country_1[metric], country_2[metric])
    
    return r, p

# %%
r , p = clean_and_correlate('Switzerland', 'Austria', 'new_cases_smoothed_per_million')
print('Pearson correlation shows an R score of: {} and a P-value of {} between {} and {}:'.format(r, p, 'Country 1', 'Country 2'))
# Out:
# Pearson correlation shows an R score of: 0.7117692348725493 and a P-value of 3.4776903211125952e-99 between Country 1 and Country 2:
# C:\Users\jakob\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\jakob\anaconda3\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# Cells below creates and saves correlation matrix. Takes up a lot of computing time

# %%
def create_correlation_matrix(k,n, metric):
    '''
    Creates a dataframe that holds the correlation values for every country with every country between k and n
    
    input: 
        k,n: index of countries in the dataset to correlate with each other
        meric: (string) metric to correlate for
    output: correlation matrix as pandas dataframe, saves the df to a csv
    '''
    
    list_of_countries = data['location'].unique()
    
    df = pd.DataFrame()
    for country_1 in list_of_countries[k:n]:
        corr_one = []
        for country_2 in list_of_countries[k:n]:
            try: 
                r , p = clean_and_correlate(country_1, country_2, metric)
                tup = (r , p)
                corr_one.append(tup)
            except:
                corr_one.append(np.nan)
        df[country_1] = corr_one
    df.set_axis(list_of_countries[k:n], axis='index', inplace = True)
    df.to_pickle('correlation_matrix.pkl')
    
    return df

# %%
create_correlation_matrix(0,len(data['location'].unique()), 'new_cases_smoothed_per_million')
# Out:
# C:\Users\jakob\AppData\Local\Temp/ipykernel_22056/963594977.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[country_1] = corr_one
# C:\Users\jakob\anaconda3\lib\site-packages\scipy\stats\stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#                                                       Afghanistan  \
# Afghanistan                                            (1.0, 0.0)
# Africa                (0.4155878204824359, 5.967957764390336e-28)
# Albania            (-0.41934193123669633, 6.9520392564858095e-28)
# Algeria              (0.23955607757591912, 9.718151716217807e-10)
# ...

# %% [markdown]
# Lets use the matrix in the following part:

# %%
 def show_corr_countries(country):
    '''
    This function gets the correlation values for the country in question and sorts them in descending order
    
    input: The country you want to investigate
    output: sorted list of correlated countries
    '''
    data = pd.read_pickle('correlation_matrix.pkl')
    corr_list = data[country].sort_values(ascending = False)
    
    return corr_list

# %%
# type the country to query for here
query_country = 'Switzerland'
# correlation results are saved for the country to query
corr_list = show_corr_countries(query_country)

# %%
corr_list.head(10)
# Out:
# Switzerland                                                  (1.0, 0.0)
# Liechtenstein             (0.8844984849687202, 4.1140751769502803e-209)
# Luxembourg                (0.8703830802564644, 1.0393887364052598e-195)
# European Union             (0.835300657038041, 1.3342555405624953e-166)
# Europe                    (0.8209404387884505, 3.4973611545027287e-156)
# High income                (0.8101790828715543, 5.713388995632424e-149)
# Italy                     (0.7908545831782285, 4.1500848027402977e-137)
# Germany                    (0.7405925103763772, 2.172832775914493e-111)
# Bosnia and Herzegovina    (0.7308339695559778, 1.3859829354768534e-105)
# Slovenia                    (0.7272693706719653, 4.43799213455446e-104)
# Name: Switzerland, dtype: object

# %% [markdown]
# Now I want to filter out the regions that are not countries and filter out the own country. The following locations in the dataset are not countries:

# %%
no_countries = ["European Union", "Europe", "High income", "North America", "World", "Upper middle income", "Asia", "Lower middle income", "Low income", "South America", "International"]

# %% [markdown]
# Filtered by these countries the top correlations look like:

# %%
corr_list = corr_list[~corr_list.index.isin(no_countries)]
corr_list.head(10)
# Out:
# Switzerland                                                  (1.0, 0.0)
# Liechtenstein             (0.8844984849687202, 4.1140751769502803e-209)
# Luxembourg                (0.8703830802564644, 1.0393887364052598e-195)
# Italy                     (0.7908545831782285, 4.1500848027402977e-137)
# Germany                    (0.7405925103763772, 2.172832775914493e-111)
# Bosnia and Herzegovina    (0.7308339695559778, 1.3859829354768534e-105)
# Slovenia                    (0.7272693706719653, 4.43799213455446e-104)
# Belgium                   (0.7258831852868919, 5.7588662487754475e-105)
# North Macedonia            (0.7134062877126361, 1.1054799664917687e-99)
# Austria                    (0.7117692348725493, 3.4776903211125952e-99)
# Name: Switzerland, dtype: object

# %% [markdown]
# Now I remove the own country and the top correlations look like:

# %%
corr_list = corr_list[corr_list.index != query_country].head(10)
corr_list.head(10)
# Out:
# Liechtenstein             (0.8844984849687202, 4.1140751769502803e-209)
# Luxembourg                (0.8703830802564644, 1.0393887364052598e-195)
# Italy                     (0.7908545831782285, 4.1500848027402977e-137)
# Germany                    (0.7405925103763772, 2.172832775914493e-111)
# Bosnia and Herzegovina    (0.7308339695559778, 1.3859829354768534e-105)
# Slovenia                    (0.7272693706719653, 4.43799213455446e-104)
# Belgium                   (0.7258831852868919, 5.7588662487754475e-105)
# North Macedonia            (0.7134062877126361, 1.1054799664917687e-99)
# Austria                    (0.7117692348725493, 3.4776903211125952e-99)
# Poland                     (0.7001369629841223, 1.6694172386391787e-93)
# Name: Switzerland, dtype: object

# %% [markdown]
# ## Results

# %%
countrylist = list(set(data.location))

# %%
def evaluate_model(country):
    '''
    This function takes a country and repeats the steps above to show correlated countries, cleans the recommendations
    to exclude locations that are not countriess and the own country. After that the function investigates the R-Values 
    and P-Values that are associated with the top ten correlated countries.
    
    A correlation is said to be significant if the p-value is smaller than 0.05
    
    Regarding the R-Value, A Correlation is said to be 
    - strong if the R-Value lies between ± 0.50 and ± 1,
    - If the value lies between ± 0.30 and ± 0.49, then it is said to be a medium correlation.
    - When the value lies below + .29, then it is said to be a small correlation.
    
    input: country
    output: 
        p_list: A list containing infor whether the p-values in the list are significant
        r_list: A list containing info whether the correlation with the country in that place of the list is strong, 
        medium or small 
    '''
    r_list = []
    p_list = []
    corr_list = show_corr_countries(country)
    corr_list = corr_list[~corr_list.index.isin(no_countries)]
    corr_list = corr_list[corr_list.index != country]
    for i in range(10):
        try:
            r_value, p_value = corr_list.iloc[i]
        except:
            r_value, p_value = (np.nan,np.nan)
        
        # analyse r_values
        if (r_value >= 0.5) & (r_value <= 1):
            r_list.append('strong')
        elif (r_value >= 0.3) & (r_value < 0.5):
            r_list.append('medium')
        elif (r_value > 0) & (r_value < 0.3):
            r_list.append('small')
        else:
            r_list.append('no correlation')
            
        #analyse p_values
        if p_value < 0.05:
            p_list.append('significant')
        else:
            p_list.append('not significant')
            
    return r_list, p_list

# %%
def run_experiment(countrylist, n):
    '''
    runs the model evaluation n times to check the predictions for multiple countries
    if there there are medium, small or, no correlations in the predictions, the recommendation is considered invalid.
    if there is an unsignificant value in the p_list, the recommendation is considered invalid.
    
    input: list of countries in the dataset, samplesize(number of countries) to run the experiment on
    output: 
        - a list containing True/False whether a valid recommendation could be made for the country in the sample
        - fraction of valid recommendations in the experiment
    '''
    sample = random.sample(countrylist, n)
    val_list = []
    for country in sample: #pick 10 countries from countrylist
        r_list, p_list = evaluate_model(country)
        
        if (Counter(r_list)['strong'] != 10) or (Counter(p_list)['significant'] != 10):
            val_list.append(False)
        else:
            val_list.append(True)
            
    frac = float(val_list.count(True)/len(val_list))
        
        
    return val_list, frac

# %%
val_list, frac = run_experiment(countrylist, 30)
val_list
# Out:
# [True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True]

# %%
frac
# Out:
# 0.7333333333333333

# %%
def plot_distribution(country):
    '''
    plots the distributions of r_values und the distribtution of p_values
    '''
    
    df =  pd.DataFrame(columns=['r_values', 'p_values'])
    corr_list = show_corr_countries(country)
    corr_list = corr_list[~corr_list.index.isin(no_countries)]
    corr_list = corr_list[corr_list.index != country]

    for i in range(len(corr_list)):
        try:
            r_value, p_value = corr_list.iloc[i]
            print(r_value)
        except:
            r_value, p_value = (np.nan,np.nan)
        df = df.append({'r_values': r_value}, ignore_index=True)
        df = df.append({'p_values': p_value}, ignore_index=True)
        
    return df

# %%
df = plot_distribution('Switzerland')
# Out:
# 0.8844984849687202
# 0.8703830802564644
# 0.7908545831782285
# 0.7405925103763772
# 0.7308339695559778
# 0.7272693706719653
# 0.7258831852868919
# 0.7134062877126361
# 0.7117692348725493
# 0.7001369629841223
# 0.6997054733056098
# 0.6922762994198538
# 0.6850586803643812
# 0.6839555783694371
# 0.6837415943202296
# 0.6528413507610968
# 0.6510693754957277
# 0.648670060582398
# 0.6440041698122891
# 0.6098355448720159
# 0.5945945667687232
# 0.5912325320660661
# 0.5850770466213779
# 0.5845392395494853
# 0.5611223865127493
# 0.5608402337863788
# 0.5464099952394307
# 0.5365180122686465
# 0.5320102348480282
# 0.5286850472245479
# 0.5220298223376291
# 0.5208522769379369
# 0.5184113358943461
# 0.4889661793327293
# 0.48684670121686774
# 0.4834904129994802
# 0.4714362684810125
# 0.4643214487933555
# 0.45202644321391994
# 0.45132170057342413
# 0.4497555494966199
# 0.4468286990725526
# 0.4417168500057539
# 0.4286619097228489
# 0.40922906641351187
# 0.4032342415474981
# 0.39201800339287207
# ...

# %%
df.hist(column = 'r_values', grid=False, bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'r_values'}>]], dtype=object)

# %%
df.hist(column = 'p_values', grid=False, bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'p_values'}>]], dtype=object)

# %% [markdown]
# For all countries:

# %%
df = pd.DataFrame()
for country in countrylist:
    df = df.append(plot_distribution(country))
# Out:
# 0.7212025788918996
# 0.7209974444102075
# 0.7167918461056452
# 0.7026271135216343
# 0.6820363662480751
# 0.6725314995283721
# 0.6445787345113779
# 0.6242614877771774
# 0.623329688755552
# 0.6184763286556361
# 0.6078585988380121
# 0.5759474558735891
# 0.5706493760897348
# 0.5681418920275338
# 0.5534479467695719
# 0.5509484332688248
# 0.5320816430481594
# 0.5315524185142493
# 0.5197792179753353
# 0.5071831766960149
# 0.5052208173653965
# 0.5049576490709952
# 0.48832917611370075
# 0.4874528424283799
# 0.4869316484674548
# 0.48090851449247496
# 0.48025311504111556
# 0.4799141360593172
# 0.47359953469302907
# 0.46557880938652596
# 0.4528858994960224
# 0.44863299579357024
# 0.443175053912175
# 0.4374547803309643
# 0.4316594816221764
# 0.4304621777281468
# 0.4043580249643237
# 0.40242387166236326
# 0.40122992120228285
# 0.383925657574247
# 0.3683841587464632
# 0.36550962331684933
# 0.3614842511217715
# 0.3610317059432058
# 0.34676249349926713
# 0.34070135709509974
# 0.3346533111946466
# ...

# %%
df
# Out:
#      r_values      p_values
# 0    0.721203           NaN
# 1         NaN  3.564577e-99
# 2    0.720997           NaN
# 3         NaN  8.973427e-99
# 4    0.716792           NaN
# ..        ...           ...
# 445       NaN           NaN
# 446       NaN           NaN
# 447       NaN           NaN
# 448       NaN           NaN
# 449       NaN           NaN
#
# [106672 rows x 2 columns]

# %%
df.shape
# Out:
# (106672, 2)

# %%
df.hist(column = 'r_values', grid=False, bins=10, color = 'g')
# Out:
# array([[<AxesSubplot:title={'center':'r_values'}>]], dtype=object)

# %%
df.hist(column = 'p_values', grid=False, bins=100, color ='g')
# Out:
# array([[<AxesSubplot:title={'center':'p_values'}>]], dtype=object)
